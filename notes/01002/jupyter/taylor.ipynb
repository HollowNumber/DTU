# %%
from sympy import *
from sympy.abc import x,y,z,u,v,w,t, E

# %% [markdown]
# # Opagave 1 c

# %%
plot(exp(x))

# %% [markdown]
# # Spørgsmål 2

# %%
s = series(sin(x), x, n=9).removeO()

p1 = plot(s, show=false)
p2 = plot(sin(x), show=false)

p1.append(p2[0])

p1.show()

# %% [markdown]
# Man kan se at grafen begynder at "diverge" ved $x=5$

# %%
series(ln(x+1) ,x, n=3).removeO()
# Out:
# -x**2/2 + x
