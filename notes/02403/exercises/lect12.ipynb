# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.power as smp
import statsmodels.stats.proportion as smprop
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %% [markdown]
# ## Exercise 7.1

# %%
grades = np.array([[20,14,16,20,12,16,10],[14,14,27,22,27,17,22]])

df = pd.DataFrame(
    grades.T,  # transpose: 7 rows x 2 cols instead of 2 rows x 7 cols
    columns=['course 1', 'course 2'],
    index=['Grade 12', 'Grade 10', 'Grade 7', 'Grade 4', 'Grade 2', 'Grade 0', 'Grade -3']
)

passed = np.array([[82, 26], [104, 39]]).T 

passed_df = pd.DataFrame(
    passed,
    columns=['course 1', 'course 2'],
    index=['Passed', 'Not passed']
)


stats.norm.ppf( 1-0.05/2 )

stats.chi2.ppf(1-0.01, 1)
# Out:
# np.float64(6.6348966010212145)

# %% [markdown]
# ## 7.2

# %%
samples = np.array([[7.2, 28.0, 8.8], [6.4, 34.8, 14.8]]) / 100 * 250


chi2, p, dof, expected = stats.chi2_contingency(samples, correction=False)

display(p > 0.05)
# Out:
# np.float64(0.33225516858504023)
# np.True_

# %% [markdown]
# b)

# %%
alpha = 1-0.05 


stats.chi2.ppf(alpha, dof)
# Out:
# np.float64(5.991464547107979)

# %% [markdown]
# ## 7.3

# %% [markdown]
# a)

# %% [markdown]
# ## 7.4

# %% [markdown]
# a)

# %%
n = 50
x_1 = 6

p_1 = x_1 / n

x_2 = 12

p_2 = x_2 / n

zobs, pval = smprop.proportions_ztest([x_1, x_2], nobs =[n,n])

print(f"{pval < 0.05}")
# Out:
# False

# %% [markdown]
# b)

# %%
n = 200 
x = 36
alpha = 0.01 
p = 36/200

z = stats.norm.ppf(1-alpha/2)

print(z)
